# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\mercg\Downloads\MP2\spotify.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum() #checking for null values
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
tg = df['playlist_genre'].value_counts()
tg.plot(kind='bar')
plt.title('Top Genres by Song Count')
plt.xlabel('Genre')
plt.ylabel('Song Count')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.hist(df['duration_ms'], bins=20, edgecolor='black')
plt.xlabel('Song Duration')
plt.ylabel('Occurences')
plt.title('Distribution of Song Durations')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.hist(df['track_popularity'], bins=20, edgecolor='black')
plt.title('Distribution of the Track Popularity')
plt.xlabel('Popularity')
plt.ylabel('Occurences')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='danceability', y='energy')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.title('Danceability vs. Energy')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='speechiness', y='instrumentalness')
plt.xlabel('speechiness')
plt.ylabel('instrumentalness')
plt.title('Speechiness vs. Instrumentalness')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='tempo', y='energy')
plt.xlabel('tempo')
plt.ylabel('energy')
plt.title('Tempo vs. Energy')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='tempo', y='danceability')
plt.xlabel('tempo')
plt.ylabel('danceability')
plt.title('Tempo vs. Danceability')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='duration_ms', y='liveness')
plt.xlabel('duration_ms')
plt.ylabel('liveness')
plt.title('Duration_ms vs. Liveness')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(data=df, x='valence', y='liveness')
plt.xlabel('valence')
plt.ylabel('liveness')
plt.title('Valence vs. Liveness')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
audio_features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence','loudness']
correlation_matrix = df[audio_features].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between the Audio Features')
plt
correlation_matrix
# Out:
#                   acousticness  danceability    energy  instrumentalness  \
# acousticness          1.000000     -0.024515 -0.539732         -0.006881
# danceability         -0.024515      1.000000 -0.086074         -0.008658
# energy               -0.539732     -0.086074  1.000000          0.033282
# instrumentalness     -0.006881     -0.008658  0.033282          1.000000
# liveness             -0.077247     -0.123899  0.161317         -0.005505
# speechiness           0.026168      0.181808 -0.032184         -0.103385
# valence              -0.016833      0.330538  0.151050         -0.175406
# loudness             -0.361646      0.025351  0.676662         -0.147823
#
#                   liveness  speechiness   valence  loudness
# acousticness     -0.077247     0.026168 -0.016833 -0.361646
# danceability     -0.123899     0.181808  0.330538  0.025351
# energy            0.161317    -0.032184  0.151050  0.676662
# instrumentalness -0.005505    -0.103385 -0.175406 -0.147823
# ...

# %%
df["playlist_genre"].value_counts()
# Out:
# playlist_genre
# edm      6043
# rap      5743
# pop      5507
# r&b      5431
# latin    5153
# rock     4951
# Name: count, dtype: int64

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6)
kmeans.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='playlist_genre', y='loudness', hue='cluster')
plt.title('Genre vs Loudness')
plt.xlabel('Playlist Genre')
plt.ylabel('loudness')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from sklearn.cluster import KMeans
kmeans1 = KMeans(n_clusters=6)
kmeans1.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='instrumentalness', y='speechiness', hue='cluster')
plt.title('Instrumentalness vs. Speechiness')
plt.xlabel('Instrumentalness')
plt.ylabel('Speechiness')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='energy', y='danceability', hue='cluster')
plt.title('Energy vs. Danceability')
plt.xlabel('Energy ')
plt.ylabel('Danceability')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness','tempo']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='tempo', y='danceability', hue='cluster')
plt.title('Tempo vs. Danceability')
plt.xlabel('Tempo')
plt.ylabel('Danceability')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness','tempo']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='tempo', y='energy', hue='cluster')
plt.title('Tempo vs. Energy')
plt.xlabel('Tempo')
plt.ylabel('Energy')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness','tempo','duration_ms']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='duration_ms', y='liveness', hue='cluster')
plt.title('Duration vs. Liveness')
plt.xlabel('Duration')
plt.ylabel('Liveness')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness','tempo']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='valence', y='liveness', hue='cluster')
plt.title('Valence vs. Liveness')
plt.xlabel('Valence')
plt.ylabel('Liveness')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6)
kmeans.fit(df[['instrumentalness', 'energy',  'acousticness' , 'liveness', 'speechiness', 'danceability', 'valence','loudness']])
df['cluster'] = kmeans.labels_
sns.scatterplot(data=df, x='playlist_name', y='loudness', hue='cluster')
plt.title('Playlist  vs. Loudness')
plt.xlabel('Playlist Name')
plt.ylabel('loudness')
plt
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128153 (\N{BLUE HEART}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 129321 (\N{GRINNING FACE WITH STAR EYES}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 129322 (\N{GRINNING FACE WITH ONE LARGE AND ONE SMALL EYE}) missing from current font.
#   func(*args, **kwargs)
# ...
